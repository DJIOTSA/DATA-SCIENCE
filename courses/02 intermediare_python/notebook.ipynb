# %%
import numpy as np
import pandas as pd

df = pd.read_csv("gapminder.csv", index_col=1)

print(df.head(5))
df.head(5)
# Out:
#              Unnamed: 0  year  population      cont  life_exp       gdp_cap
# country
# Afghanistan          11  2007  31889923.0      Asia    43.828    974.580338
# Albania              23  2007   3600523.0    Europe    76.423   5937.029526
# Algeria              35  2007  33333216.0    Africa    72.301   6223.367465
# Angola               47  2007  12420476.0    Africa    42.731   4797.231267
# Argentina            59  2007  40301927.0  Americas    75.320  12779.379640
#              Unnamed: 0  year  population      cont  life_exp       gdp_cap
# country
# Afghanistan          11  2007  31889923.0      Asia    43.828    974.580338
# Albania              23  2007   3600523.0    Europe    76.423   5937.029526
# Algeria              35  2007  33333216.0    Africa    72.301   6223.367465
# Angola               47  2007  12420476.0    Africa    42.731   4797.231267
# Argentina            59  2007  40301927.0  Americas    75.320  12779.379640

# %%
df[0:25]
# Out:
#                           Unnamed: 0  year    population      cont  life_exp  \
# country
# Afghanistan                       11  2007  3.188992e+07      Asia    43.828
# Albania                           23  2007  3.600523e+06    Europe    76.423
# Algeria                           35  2007  3.333322e+07    Africa    72.301
# Angola                            47  2007  1.242048e+07    Africa    42.731
# Argentina                         59  2007  4.030193e+07  Americas    75.320
# Australia                         71  2007  2.043418e+07   Oceania    81.235
# Austria                           83  2007  8.199783e+06    Europe    79.829
# Bahrain                           95  2007  7.085730e+05      Asia    75.635
# Bangladesh                       107  2007  1.504483e+08      Asia    64.062
# Belgium                          119  2007  1.039223e+07    Europe    79.441
# Benin                            131  2007  8.078314e+06    Africa    56.728
# ...

# %%
df.loc[['Afghanistan','China'],['year','population']]
# Out:
#              year    population
# country
# Afghanistan  2007  3.188992e+07
# China        2007  1.318683e+09
